# %% [markdown]
# ## NAME: BISMARK AKOTO
# ## ID: 10958565
# ## DEPARTMENT: MATERIALS SCIENCE AND ENGINEERING
# ____

# %% [markdown]
# #### IMPORTING PACKAGES FOR DATA ANALYSIS
# #### pandas, matplotlib and seaborn
# ---

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# #### USING THE GIVEN DATA FILE 'data.csv'
# ---

# %%
# assigning datase to the information in the data.csv file.
dataframe = pd.read_csv('data.csv')

# %% [markdown]
# #### ANALYSING AND REMOVING ALL NULL VALUES AND DUPLICATES
# ---

# %%
# Replacing the spaces between words in the columns with underscores '_'
dataframe.columns = dataframe.columns.str.replace(' ','_')

# %%
dataframe
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %%
#Checking the data information
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed_acidity         1600 non-null   float64
#  2   volatile_acidity      1601 non-null   float64
#  3   citric_acid           1600 non-null   float64
#  4   residual_sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free_sulfur_dioxide   1600 non-null   float64
#  7   total_sulfur_dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %% [markdown]
# The isnull() method is used to check whether a value in a pandas DataFrame or series is missing or not. This method returns a boolean mask indicating where the values are null(True) or non null(false)

# %%
# Checking for the total number of null values
dataframe.isnull().sum()
# Out:
# ID                      0
# fixed_acidity           1
# volatile_acidity        0
# citric_acid             1
# residual_sugar          0
# chlorides               3
# free_sulfur_dioxide     1
# total_sulfur_dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
#Finding the mean values of each column
meanDATA = dataframe.mean()

# %%
# This variable represents the mean of each of the dataframe
meanDATA
# Out:
# ID                      801.000000
# fixed_acidity             8.319875
# volatile_acidity          0.527742
# citric_acid               0.271175
# residual_sugar            2.538445
# chlorides                 0.087487
# free_sulfur_dioxide      15.886875
# total_sulfur_dioxide     46.520000
# density                   0.996746
# pH                        3.311106
# sulphates                 0.658220
# alcohol                  10.423204
# quality                   5.636250
# dtype: float64

# %% [markdown]
# #### REPLACING ALL THE NULL VALUES WITH THE MEAN OF EACH COLUMN AND REMOVING ALL DUPLICATES
# ---

# %%
dataframe = dataframe.fillna(meanDATA).drop_duplicates()

# %%
meanFA = dataframe.fixed_acidity.mean()
meanVA = dataframe.volatile_acidity.mean()
meanCA = dataframe.citric_acid.mean()
meanRS = dataframe.residual_sugar.mean()
meanC = dataframe.chlorides.mean()
meanFSD = dataframe.free_sulfur_dioxide.mean()
meanTSD = dataframe.total_sulfur_dioxide.mean()
meanD = dataframe.density.mean()
meanPH = dataframe.pH.mean()
meanS = dataframe.sulphates.mean()
meanA = dataframe.alcohol.mean()
meanQ = dataframe.quality.mean()

# %% [markdown]
# #### SUMMARY OF THE STATISTICS OF THE DATAFRAME
# ___

# %% [markdown]
# Describe() method gives us the count, mean, standard deviation, minimum, and maximum values of the dataframe or individual columns.

# %%
dataframe.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1601.000000    1600.000000       1601.000000  1600.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.740039          0.178981     0.194745
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulfur_dioxide  total_sulfur_dioxide  \
# count     1601.000000  1598.000000          1600.000000           1600.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047076            10.458487             32.977723
# ...

# %% [markdown]
# #### MEAN FOR EACH COLUMN
# ___

# %%
print(f'The mean value of fixed_acidity  is {meanFA}')
print(f'The mean value of volatile_acidity is {meanVA}')
print(f'The mean value of citric_acid is {meanCA}')
print(f'The mean value of residual_sugar is {meanRS}')
print(f'The mean value of chlorides is {meanC}')
print(f'The mean value of free_sulfur_dioxide is {meanFSD}')
print(f'The mean value of total_sulfur_dioxide is {meanTSD}')
print(f'The mean value of density is {meanD}')
print(f'The mean value of pH is {meanPH}')
print(f'The mean value of sulphate is {meanS}')
print(f'The mean value of alcohol is {meanA}')
print(f'The mean value of quality is {meanQ}')
# Out:
# The mean value of fixed_acidity  is 8.319875
# The mean value of volatile_acidity is 0.5277420362273579
# The mean value of citric_acid is 0.27117500000000005
# The mean value of residual_sugar is 2.5384447220487196
# The mean value of chlorides is 0.0874874843554443
# The mean value of free_sulfur_dioxide is 15.886875
# The mean value of total_sulfur_dioxide is 46.52
# The mean value of density is 0.9967456437500001
# The mean value of pH is 3.3111062500000004
# The mean value of sulphate is 0.6582198625858838
# The mean value of alcohol is 10.42320424734541
# The mean value of quality is 5.6362499999999995

# %%
dataframe
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# #### GRAPHING THE DATA
# ___

# %%
# data for pie chart
# total columns excluding ID is 12
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'purple',
          'pink', 'brown', 'gray', 'black', 'violet', 'beige']
explode = (0.5, 0.5, 1, 1, 1, 0, 0, 0.5, 0, 0.5, 0, 0.5)
meanValues = [meanFA, meanVA, meanCA, meanRS, meanC,
              meanFSD, meanTSD, meanD, meanPH, meanS, meanA, meanQ]
meanTopics = ['FA',
              'VA',
              'CA',
              'RS',
              'C',
              'FSD',
              'TSD',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']

# %%
xtitle = 'Column names'
ytitle = 'Mean Values'
legendLabels = ['fixed_acidity (FA)',
                'volatile_acidity (VA)',
                'citric_acid (CA)',
                'residual_sugar (RS)',
                'chlorides (C)',
                'free_sulfur_dioxide (FSD)',
                'total_sulfur_dioxide (TSD)',
                'density',
                'pH',
                'sulphates',
                'alcohol',
                'quality']

# %%
labels = meanTopics
sizes = meanValues

# %% [markdown]
# #### COMPARING THE MEAN VALUES OF THE DATA USING A PIE CHART
# ___

# %%
# plotting the pie chart
plt.pie(sizes, labels=labels, explode=explode,
        autopct='%1.1f%%', pctdistance=1.01, shadow=True, colors=colors, labeldistance=1.2)
plt.axis('equal')
plt.legend(title='index', labels=legendLabels, loc='upper right',)
plt.title('Mean Values for each of the columns in a pie chart')
plt.figure(figsize=(15, 18))
plt.show()

# %% [markdown]
# #### COMPARING THE MEAN VALUES OF THE DATA USING A BAR GRAPH
# ___

# %%
# plotting a bar graph

fig = plt.figure(figsize = (10, 5))

plt.bar(labels, sizes, width = 0.5, color = colors)
plt.xlabel(xtitle)
plt.ylabel(ytitle)
plt.title('Comparing mean of columns in a bar chart')
plt.show()

# %%
dataframe
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...

# %% [markdown]
# #### HISTOGRAM OF EACH COLUMN IN THE DATASET
# ___

# %%
# Histogram of Columns
sns.histplot(data=dataframe, x=dataframe.fixed_acidity)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe.volatile_acidity)
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe.citric_acid)
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe.residual_sugar)
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['chlorides'])
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['free_sulfur_dioxide'])
# Out:
# <Axes: xlabel='free_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['total_sulfur_dioxide'])
# Out:
# <Axes: xlabel='total_sulfur_dioxide', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['density'])
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['pH'])
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['sulphates'])
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
sns.histplot(data=dataframe, x=dataframe['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# #### DATA CORRELATION
# ___

# %%
dataframecorr = dataframe.corr()

# %%
dataframecorr
# Out:
#                             ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                    1.000000      -0.268147         -0.009544    -0.153429
# fixed_acidity        -0.268147       1.000000         -0.255570     0.671061
# volatile_acidity     -0.009544      -0.255570          1.000000    -0.552917
# citric_acid          -0.153429       0.671061         -0.552917     1.000000
# residual_sugar       -0.031589       0.114601          0.001877     0.143518
# chlorides            -0.119363       0.093544          0.060826     0.204054
# free_sulfur_dioxide   0.091197      -0.153049         -0.010592    -0.061269
# total_sulfur_dioxide -0.113913      -0.113356          0.076249     0.036030
# density              -0.368825       0.667912          0.022771     0.364309
# pH                    0.135208      -0.682644          0.235306    -0.543019
# sulphates            -0.124243       0.182303         -0.261364     0.312895
# ...

# %% [markdown]
# #### HEATMAP OF THE DATA CORRELATION
# ___

# %% [markdown]
# The correlation matrix gives us the correlation coefficient betwwen each pair of columns in the dataframe. A positive correlation coefficient indicates a positive relationship between the variables, while a negative correlation indicates a negative relationship. A coefficient of 0 indicates no relation.

# %%
sns.heatmap(dataframecorr, annot=True, fmt='0.1g')
# Out:
# <Axes: >

# %%
plt.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...

# %% [markdown]
# ## INFERENCES
# ___

# %% [markdown]
# ### Since the company is a wine company,the focus would be on the <strong>quality</strong>
#
# ---
#
# | Parameter            | Correlation with wine quality | Inference                                                                    |
# | -------------------- | ----------------------------- | ---------------------------------------------------------------------------- |
# | fixed_acidity        | 0.1                           | Quality slightly increases with an increase in the fixed acidity             |
# | volatile acidity     | -0.4                          | Quality decreases with an increase in volatile acidity                       |
# | citric_acid          | 0.2                           | Quality slightly increases with an increase in citric acid concentration     |
# | residual_sugar       | 0.01                          | There is a negligible increase in Quality with an increase in residual sugar |
# | chlorides            | -0.1                          | Quality slightly decreases with increasing concentration of chlorides        |
# | free_sulfur_dioxide  | -0.05                         | Quality barely decreases with increasing free sulphur dioxide                |
# | total_sulfur_dioxide | -0.2                          | Quality decreases with increasing total sulphur dioxide concentration        |
# | density              | -0.2                          | Quality decreases with increasing density                                    |
# | pH                   | -0.06                         | Quality barely decreases with increasing pH                                  |
# | sulphates            | 0.3                           | Quality slightly increases with increasing sulphates                         |
# | alcohol              | 0.5                           | Quality increases with increasing alcohol                                    |

# %% [markdown]
# PROJECT ONE - BISMARK AKOTO (10958565) MTEN
# ________
